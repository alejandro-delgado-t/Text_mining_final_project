# %%
import pandas as pd

# %%
df = pd.read_csv('billboard_hot_100_1981_2022_with_lyrics_vf.csv')

df.head()
# Out:
#    year  ranking                      title                      artist  \
# 0  1981        1           Bette Davis Eyes                  Kim Carnes
# 1  1981        2               Endless Love  Diana Ross & Lionel Richie
# 2  1981        3                       Lady                Kenny Rogers
# 3  1981        4  (Just Like) Starting Over                 John Lennon
# 4  1981        5              Jessie's Girl            Rick Springfield
#
#                                               lyrics  \
# 0  [Verse 1]\nHer hair is Harlow gold\nHer lips s...
# 1  [Verse 1: Lionel Richie & Diana Ross]\nMy love...
# 2  [Verse 1]\nLady\nI'm your knight in shining ar...
# 3  [Intro]\nOur life together is so precious toge...
# 4  [Verse 1]\nJessie is a friend\nYeah, I know, h...
#
#                                             song_url  \
# 0  https://genius.com/kim-carnes-bette-davis-eyes...
# 1  https://genius.com/diana-ross-and-lionel-richi...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4182 entries, 0 to 4181
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         4182 non-null   int64
#  1   ranking      4182 non-null   int64
#  2   title        4182 non-null   object
#  3   artist       4182 non-null   object
#  4   lyrics       4154 non-null   object
#  5   song_url     4182 non-null   object
#  6   producers    4103 non-null   object
#  7   writers      4109 non-null   object
#  8   label        2580 non-null   object
#  9   released_on  4111 non-null   object
#  10  tags         4154 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 359.5+ KB
